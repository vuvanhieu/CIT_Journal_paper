# %%
import matplotlib.pyplot as plt
import numpy as np

# Updated combined_metrics dictionary without 'Training Time'
combined_metrics = {
    'KNN': {
        'ROC-AUC': 0.794,
        'AUC-PR': 0.483,
        'Accuracy': 0.758,
        'Error Rate': 0.242,
        'Sensitivity': 0.685,
        'Specificity': 0.777,
        'Precision': 0.442,
        'Recall': 0.685,
        'F1-score': 0.537
    },
    'RF': {
        'ROC-AUC': 0.854,
        'AUC-PR': 0.662,
        'Accuracy': 0.840,
        'Error Rate': 0.160,
        'Sensitivity': 0.563,
        'Specificity': 0.911,
        'Precision': 0.619,
        'Recall': 0.563,
        'F1-score': 0.590
    },
    'SVM': {
        'ROC-AUC': 0.847,
        'AUC-PR': 0.643,
        'Accuracy': 0.792,
        'Error Rate': 0.208,
        'Sensitivity': 0.724,
        'Specificity': 0.809,
        'Precision': 0.495,
        'Recall': 0.724,
        'F1-score': 0.588
    },
    'XGB': {
        'ROC-AUC': 0.844,
        'AUC-PR': 0.655,
        'Accuracy': 0.822,
        'Error Rate': 0.178,
        'Sensitivity': 0.593,
        'Specificity': 0.881,
        'Precision': 0.562,
        'Recall': 0.593,
        'F1-score': 0.577
    },
    'Scenario 1': {
        'ROC-AUC': 0.984,
        'AUC-PR': 0.984,
        'Accuracy': 0.903,
        'Error Rate': 0.097,
        'Sensitivity': 0.820,
        'Specificity': 0.985,
        'Precision': 0.981,
        'Recall': 0.820,
        'F1-score': 0.893
    },
    'Scenario 2': {
        'ROC-AUC': 0.986,
        'AUC-PR': 0.987,
        'Accuracy': 0.915,
        'Error Rate': 0.499,
        'Sensitivity': 0.836,
        'Specificity': 0.992,
        'Precision': 0.990,
        'Recall': 0.836,
        'F1-score': 0.907
    },
    'Scenario 3': {
        'ROC-AUC': 0.978,
        'AUC-PR': 0.979,
        'Accuracy': 0.879,
        'Error Rate': 0.498,
        'Sensitivity': 0.768,
        'Specificity': 0.987,
        'Precision': 0.983,
        'Recall': 0.768,
        'F1-score': 0.862
    }
}

def plot_metric_comparison(metrics_dict):
    models = list(metrics_dict.keys())
    metrics = list(metrics_dict[models[0]].keys())
    colors = plt.cm.get_cmap('tab10', len(models)).colors
    
    fig, axs = plt.subplots(len(metrics), 1, figsize=(10, 5 * len(metrics)))
    
    for i, metric in enumerate(metrics):
        values = [metrics_dict[model][metric] for model in models]
        for j, val in enumerate(values):
            axs[i].bar(models[j], val, color=colors[j])
            axs[i].text(j, val, f'{val:.3f}', ha='center', va='bottom')
        axs[i].set_title(f'{metric}')
        axs[i].set_ylabel(metric)
        axs[i].tick_params(axis='x', rotation=45)
    
    plt.tight_layout()
    plt.show()

plot_metric_comparison(combined_metrics)
# Out:
# C:\Users\vuvan\AppData\Local\Temp\ipykernel_11280\4214576391.py:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(models)).colors

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# Updated combined_metrics dictionary without 'Training Time'
combined_metrics = {
    'KNN': {
        'ROC-AUC': 0.794,
        'AUC-PR': 0.483,
        'Accuracy': 0.758,
        'Error Rate': 0.242,
        'Sensitivity': 0.685,
        'Specificity': 0.777,
        'Precision': 0.442,
        'Recall': 0.685,
        'F1-score': 0.537
    },
    'RF': {
        'ROC-AUC': 0.854,
        'AUC-PR': 0.662,
        'Accuracy': 0.840,
        'Error Rate': 0.160,
        'Sensitivity': 0.563,
        'Specificity': 0.911,
        'Precision': 0.619,
        'Recall': 0.563,
        'F1-score': 0.590
    },
    'SVM': {
        'ROC-AUC': 0.847,
        'AUC-PR': 0.643,
        'Accuracy': 0.792,
        'Error Rate': 0.208,
        'Sensitivity': 0.724,
        'Specificity': 0.809,
        'Precision': 0.495,
        'Recall': 0.724,
        'F1-score': 0.588
    },
    'XGB': {
        'ROC-AUC': 0.844,
        'AUC-PR': 0.655,
        'Accuracy': 0.822,
        'Error Rate': 0.178,
        'Sensitivity': 0.593,
        'Specificity': 0.881,
        'Precision': 0.562,
        'Recall': 0.593,
        'F1-score': 0.577
    },
    'Scenario 1': {
        'ROC-AUC': 0.984,
        'AUC-PR': 0.984,
        'Accuracy': 0.903,
        'Error Rate': 0.097,
        'Sensitivity': 0.820,
        'Specificity': 0.985,
        'Precision': 0.981,
        'Recall': 0.820,
        'F1-score': 0.893
    },
    'Scenario 2': {
        'ROC-AUC': 0.986,
        'AUC-PR': 0.987,
        'Accuracy': 0.915,
        'Error Rate': 0.499,
        'Sensitivity': 0.836,
        'Specificity': 0.992,
        'Precision': 0.990,
        'Recall': 0.836,
        'F1-score': 0.907
    },
    'Scenario 3': {
        'ROC-AUC': 0.978,
        'AUC-PR': 0.979,
        'Accuracy': 0.879,
        'Error Rate': 0.498,
        'Sensitivity': 0.768,
        'Specificity': 0.987,
        'Precision': 0.983,
        'Recall': 0.768,
        'F1-score': 0.862
    }
}

def plot_metric_comparison(metrics_dict, save_folder):
    if not os.path.exists(save_folder):
        os.makedirs(save_folder)
        
    models = list(metrics_dict.keys())
    metrics = list(metrics_dict[models[0]].keys())
    colors = plt.cm.get_cmap('tab10', len(models)).colors
    
    for i, metric in enumerate(metrics):
        fig, ax = plt.subplots(figsize=(10, 5))
        values = [metrics_dict[model][metric] for model in models]
        for j, val in enumerate(values):
            ax.bar(models[j], val, color=colors[j])
            ax.text(j, val, f'{val:.3f}', ha='center', va='bottom')
        # ax.set_title(f'{metric}')
        ax.set_ylabel(metric)
        ax.tick_params(axis='x', rotation=45)
        
        plt.tight_layout()
        fig.savefig(os.path.join(save_folder, f'{metric}.png'))
        plt.close(fig)

save_folder = 'comparing_data_set_1'
plot_metric_comparison(combined_metrics, save_folder)
# Out:
# C:\Users\vuvan\AppData\Local\Temp\ipykernel_11280\1358377554.py:92: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(models)).colors

# %%
def plot_metric_comparison(metrics_dict, save_folder):
    if not os.path.exists(save_folder):
        os.makedirs(save_folder)
        
    models = list(metrics_dict.keys())
    metrics = list(metrics_dict[models[0]].keys())
    colors = plt.cm.get_cmap('tab10', len(models)).colors
    
    for i, metric in enumerate(metrics):
        fig, ax = plt.subplots(figsize=(10, 8))
        values = [metrics_dict[model][metric] for model in models]
        for j, val in enumerate(values):
            ax.bar(models[j], val, color=colors[j])
            ax.text(j, val, f'{val:.3f}', ha='center', va='bottom', fontsize=12)
        # ax.set_title(f'{metric}')
        ax.set_ylabel(metric, fontsize=12)
        ax.tick_params(axis='x', rotation=45, labelsize=14)
        ax.tick_params(axis='y', labelsize=10)
        
        plt.tight_layout()
        fig.savefig(os.path.join(save_folder, f'{metric}.png'))
        plt.close(fig)

save_folder = 'comparing_data_set_1'
plot_metric_comparison(combined_metrics, save_folder)
# Out:
# C:\Users\vuvan\AppData\Local\Temp\ipykernel_11280\3856776917.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(models)).colors
